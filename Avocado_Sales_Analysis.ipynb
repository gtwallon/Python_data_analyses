# %% [markdown]
# ___

# %% [markdown]
# # Recitation 12

# %% [markdown]
# ___
#
# Topic: Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Avocado Prices
#
# **Read in the file** `'avocado.csv'` as a pandas dataframe called **`dfavo`**. The file, downloaded from kaggle.com, contains Hass Avocado Board data on avocado prices and sales volume in multiple US markets from January 4, 2015, to March 25, 2018.
#
# * **Date:** Date of observation
# * **AveragePrice:** Average price of a single avocado
# * **TotalVolume:** Total number of avocados sold
# * **PLU4046:** Total number of avocados with PLU 4046 sold (small to medium)
# * **PLU4225:** Total number of avocados with PLU 4225 sold (large)
# * **PLU4770:** Total number of avocados with PLU 4770 sold (extra-large)
# * **SmallBags:** Number of small bags sold
# * **LargeBags:** Number of large bags sold
# * **XLargeBags:** Number of extra-large bags sold
# * **Type:** conventional or organic
# * **Region:** City or region of observation

# %%
dfavo = pd.read_csv("avocado.csv")

# %% [markdown]
# ### Basic Information
# Store values in following the variables.
# * Let **`avo_rows_cols`** be a 2-element tuple `(nrows, ncols)` containing the number of rows and columns, respectively, in `dfavo`
# * Let **`avo_col_names`** be the column names of `dfavo` in array format (use `.values`).
# * Let **`avo_first_5_rows`** be the first 5 rows of `dfavo`
# * Let **`avo_last_2_rows`** be the last 2 rows of `dfavo`

# %%
avo_rows_cols = dfavo.shape
# avo_rows_cols

# %%
avo_col_names = dfavo.columns.values
# avo_col_names

# %%
avo_first_5_rows = dfavo.head()
avo_first_5_rows
# Out:
#       Date  AveragePrice  TotalVolume  PLU4046   PLU4225  PLU4770  SmallBags  \
# 0   1/4/15          1.22     40873.28  2819.50  28287.42    49.90    9186.93
# 1  1/11/15          1.24     41195.08  1002.85  31640.34   127.12    8036.04
# 2  1/18/15          1.17     44511.28   914.14  31540.32   135.77   11651.09
# 3  1/25/15          1.06     45147.50   941.38  33196.16   164.14   10103.35
# 4   2/1/15          0.99     70873.60  1353.90  60017.20   179.32    9170.82
#
#    LargeBags  XLargeBags          Type  Region
# 0     529.53         0.0  conventional  Albany
# 1     388.73         0.0  conventional  Albany
# 2     269.96         0.0  conventional  Albany
# 3     742.47         0.0  conventional  Albany
# 4     152.36         0.0  conventional  Albany

# %%
avo_last_2_rows = dfavo.tail()
avo_last_2_rows
# Out:
#           Date  AveragePrice  TotalVolume  PLU4046  PLU4225  PLU4770  \
# 15878  2/25/18          1.57     18421.24  1974.26  2482.65     0.00
# 15879   3/4/18          1.54     17393.30  1832.24  1905.57     0.00
# 15880  3/11/18          1.56     22128.42  2162.67  3194.25     8.93
# 15881  3/18/18          1.56     15896.38  2055.35  1499.55     0.00
# 15882  3/25/18          1.62     15303.40  2325.30  2171.66     0.00
#
#        SmallBags  LargeBags  XLargeBags     Type            Region
# 15878   13698.27     266.06         0.0  organic  WestTexNewMexico
# 15879   13401.93     253.56         0.0  organic  WestTexNewMexico
# 15880   16510.32     252.25         0.0  organic  WestTexNewMexico
# 15881   12114.81     226.67         0.0  organic  WestTexNewMexico
# 15882   10569.80     236.64         0.0  organic  WestTexNewMexico

# %% [markdown]
# **`.info()`** to display the column names, counts, and data types.

# %%
dfavo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15883 entries, 0 to 15882
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          15883 non-null  object
#  1   AveragePrice  15883 non-null  float64
#  2   TotalVolume   15883 non-null  float64
#  3   PLU4046       15883 non-null  float64
#  4   PLU4225       15883 non-null  float64
#  5   PLU4770       15883 non-null  float64
#  6   SmallBags     15883 non-null  float64
#  7   LargeBags     15883 non-null  float64
#  8   XLargeBags    15883 non-null  float64
#  9   Type          15883 non-null  object
#  10  Region        15883 non-null  object
# dtypes: float64(8), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# **`.describe()`** to display statistics for columns with numerical data.

# %%
dfavo.describe()
# Out:
#        AveragePrice   TotalVolume       PLU4046       PLU4225       PLU4770  \
# count  15883.000000  1.588300e+04  1.588300e+04  1.588300e+04  1.588300e+04
# mean       1.412121  6.728983e+05  2.323957e+05  2.343862e+05  1.841391e+04
# std        0.410441  3.562877e+06  1.285378e+06  1.233057e+06  1.070686e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  9.017130e+03  6.099800e+02  2.326270e+03  0.000000e+00
# 50%        1.370000  8.110474e+04  5.754480e+03  2.166596e+04  1.182500e+02
# 75%        1.670000  3.560994e+05  8.813346e+04  1.120174e+05  4.457955e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#           SmallBags     LargeBags     XLargeBags
# count  1.588300e+04  1.588300e+04   15883.000000
# mean   1.454642e+05  3.968667e+04    2550.306785
# std    7.703888e+05  2.372885e+05   17784.171151
# min    0.000000e+00  0.000000e+00       0.000000
# 25%    2.018290e+03  5.417500e+01       0.000000
# 50%    1.961320e+04  1.742220e+03       0.000000
# 75%    6.962589e+04  1.346210e+04      59.590000
# max    1.338459e+07  5.719097e+06  551693.650000

# %% [markdown]
# ### Separate U.S. and Regional Data
# * Let **`avo_regions`** be an array containing the **distinct** names in the `Region` column. (Use `unique()`.)
# * Note that one of the `Region` names is `'TotalUS'`. Use queries to separate the `'TotalUS'` rows from the rest.
#   * Let **`dfUS`** be a dataframe containing the rows with region `'TotalUS'`.
#   * Let **`dfRegional`** be a dataframe containing the remaining rows.

# %%
avo_regions = dfavo.Region.unique()
avo_regions
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Nashville', 'NewOrleansMobile', 'NewYork', 'NorthernNewEngland',
#        'Orlando', 'Philadelphia', 'PhoenixTucson', 'Pittsburgh',
#        'Portland', 'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke',
#        'Sacramento', 'SanDiego', 'SanFrancisco', 'Seattle',
#        'SouthCarolina', 'Spokane', 'StLouis', 'Syracuse', 'Tampa',
#        'TotalUS', 'WestTexNewMexico'], dtype=object)

# %%
dfUS = dfavo[dfavo.Region == 'TotalUS']
dfUS
# Out:
#           Date  AveragePrice  TotalVolume      PLU4046      PLU4225  \
# 7605    1/4/15          0.95  31324277.73  12357161.34  13624083.05
# 7606   1/11/15          1.01  29063542.75  11544810.53  12134773.38
# 7607   1/18/15          1.03  29043458.85  11858139.34  11701947.80
# 7608   1/25/15          1.04  28470310.84  12167445.03  10734652.82
# 7609    2/1/15          0.89  44655461.51  18933038.04  18956479.74
# ...        ...           ...          ...          ...          ...
# 15712  2/25/18          1.57   1459852.55    122912.97    340374.83
# 15713   3/4/18          1.52   1634430.77    142345.03    390129.50
# 15714  3/11/18          1.52   1664234.88    129169.72    408763.50
# 15715  3/18/18          1.54   1675804.22    170801.85    444949.69
# 15716  3/25/18          1.55   1559967.20    121007.94    342853.10
#
#           PLU4770   SmallBags   LargeBags  XLargeBags          Type   Region
# 7605    844093.32  3585321.58   894945.63    18672.81  conventional  TotalUS
# 7606    866574.66  3783261.16   718333.87    15789.15  conventional  TotalUS
# 7607    831301.90  3873041.26   771093.20     7935.35  conventional  TotalUS
# 7608    768020.05  3978636.90   812924.73     8631.31  conventional  TotalUS
# 7609   1381516.11  4216452.03  1121076.47    46899.12  conventional  TotalUS
# ...           ...         ...         ...         ...           ...      ...
# 15712     1063.32   765056.82   229158.56      256.12       organic  TotalUS
# 15713     1225.97   831885.50   267818.31      167.87       organic  TotalUS
# 15714     1401.87   944572.50   180049.00        0.00       organic  TotalUS
# 15715     1045.38   837351.85   221129.46      170.19       organic  TotalUS
# 15716     1070.24   902774.79   190941.84      144.46       organic  TotalUS
#
# [338 rows x 11 columns]

# %%
dfRegional = dfavo[dfavo.Region != 'TotalUS']
dfRegional
# Out:
#           Date  AveragePrice  TotalVolume  PLU4046   PLU4225  PLU4770  \
# 0       1/4/15          1.22     40873.28  2819.50  28287.42    49.90
# 1      1/11/15          1.24     41195.08  1002.85  31640.34   127.12
# 2      1/18/15          1.17     44511.28   914.14  31540.32   135.77
# 3      1/25/15          1.06     45147.50   941.38  33196.16   164.14
# 4       2/1/15          0.99     70873.60  1353.90  60017.20   179.32
# ...        ...           ...          ...      ...       ...      ...
# 15878  2/25/18          1.57     18421.24  1974.26   2482.65     0.00
# 15879   3/4/18          1.54     17393.30  1832.24   1905.57     0.00
# 15880  3/11/18          1.56     22128.42  2162.67   3194.25     8.93
# 15881  3/18/18          1.56     15896.38  2055.35   1499.55     0.00
# 15882  3/25/18          1.62     15303.40  2325.30   2171.66     0.00
#
#        SmallBags  LargeBags  XLargeBags          Type            Region
# 0        9186.93     529.53         0.0  conventional            Albany
# 1        8036.04     388.73         0.0  conventional            Albany
# 2       11651.09     269.96         0.0  conventional            Albany
# 3       10103.35     742.47         0.0  conventional            Albany
# 4        9170.82     152.36         0.0  conventional            Albany
# ...          ...        ...         ...           ...               ...
# 15878   13698.27     266.06         0.0       organic  WestTexNewMexico
# 15879   13401.93     253.56         0.0       organic  WestTexNewMexico
# 15880   16510.32     252.25         0.0       organic  WestTexNewMexico
# 15881   12114.81     226.67         0.0       organic  WestTexNewMexico
# 15882   10569.80     236.64         0.0       organic  WestTexNewMexico
#
# [15545 rows x 11 columns]

# %% [markdown]
# ### Average Prices in the U.S.
# For the following commands, **use `dfUS`**.
# * Apply `.max()` and `.min()` to `dfUS` to show the max and min values for each column.
# * Let **`avgprice_max`** be the largest value in the `AveragePrice` column.
# * Let **`avgprice_min`** be the smallest value in the `AveragePrice` column.
# * Let **`avgprice_max_rows`** correspond to the 3 rows that contain the highest `AveragePrice`.
# * Let **`avgprice_min_rows`** correspond to the 5 rows that contain the lowest `AveragePrice`.
# * Let **`avgprice_min_dates`** be an **array** containing the dates in **`avgprice_min_rows`**. (Use `.values` to convert a series into an array. Can you guess why prices were low during those weeks?)

# %%
dfUS.max()
# Out:
# Date                 9/6/15
# AveragePrice           2.09
# TotalVolume     62505646.52
# PLU4046         22743616.17
# PLU4225         20470572.61
# PLU4770          2546439.11
# SmallBags        13384586.8
# LargeBags        5719096.61
# XLargeBags        551693.65
# Type                organic
# Region              TotalUS
# dtype: object

# %%
dfUS.min()
# Out:
# Date                  1/1/17
# AveragePrice            0.76
# TotalVolume        501814.87
# PLU4046             77759.93
# PLU4225            198874.09
# PLU4770                834.3
# SmallBags            71807.0
# LargeBags           22985.22
# XLargeBags               0.0
# Type            conventional
# Region               TotalUS
# dtype: object

# %%
avgprice_max = dfUS.AveragePrice.max()
avgprice_max
# Out:
# 2.09

# %%
avgprice_min = dfUS.AveragePrice.min()
avgprice_min
# Out:
# 0.76

# %%
avgprice_max_rows = dfUS.nlargest(3, 'AveragePrice')
avgprice_max_rows
# Out:
#           Date  AveragePrice  TotalVolume    PLU4046    PLU4225  PLU4770  \
# 15686  8/27/17          2.09   1045992.02  112812.39  250861.84  2119.14
# 15687   9/3/17          2.06   1075538.53  113516.00  256920.07  2256.96
# 15688  9/10/17          2.03   1093955.66  114942.21  249231.14   940.89
#
#        SmallBags  LargeBags  XLargeBags     Type   Region
# 15686  588832.95   91249.96        5.30  organic  TotalUS
# 15687  571725.58  130801.89      101.44  organic  TotalUS
# 15688  622445.79  106080.90      132.23  organic  TotalUS

# %%
avgprice_min_rows = dfUS.nsmallest(5, 'AveragePrice')
avgprice_min_rows
# Out:
#         Date  AveragePrice  TotalVolume      PLU4046      PLU4225     PLU4770  \
# 7662  2/7/16          0.76  52288697.89  16573573.78  20470572.61  2546439.11
# 7714  2/5/17          0.77  61034457.10  22743616.17  20328161.55  1664383.09
# 7675  5/8/16          0.82  46324529.70  14223304.98  17896391.60  1993645.36
# 7674  5/1/16          0.84  42867608.54  13748944.38  15899858.37  1414364.49
# 7657  1/3/16          0.86  38142088.04  11616506.17  16054083.86  1560068.62
#
#         SmallBags   LargeBags  XLargeBags          Type   Region
# 7662   9083373.04  3373077.87   241661.48  conventional  TotalUS
# 7714  12567155.58  3618270.75   112869.96  conventional  TotalUS
# 7675   8747756.84  3342780.83   120650.09  conventional  TotalUS
# 7674   8376124.32  3365582.11    62734.87  conventional  TotalUS
# 7657   6464895.83  2287449.76   159083.80  conventional  TotalUS

# %%
avgprice_min_dates = avgprice_min_rows.Date.values
avgprice_min_dates
# Out:
# array(['2/7/16', '2/5/17', '5/8/16', '5/1/16', '1/3/16'], dtype=object)

# %% [markdown]
# ### Conventional and Organic
# For the following commands, **use `dfRegional`**.
#
# * Notice that the rows with the smallest `TotalVolume` are for organic avocados and the rows with the largest are for conventional avocados.
#
#
# * Let **`dfOrg`** represent the rows corresponding to organic avocados.
# * Let **`dfConv`** represent the rows corresponding to conventional avocados.
#
#
# * Let **`org_vol_max_regions`** be an array containing the distinct region(s) with the 5 largest organic `TotalVolume`s. (Use `unique()`.)
# * Let **`conv_vol_min_regions`** be an array containing the distinct region(s) with the 5 smallest conventional `TotalVolume`s.

# %%
dfRegional.nsmallest(3,'TotalVolume')
# Out:
#            Date  AveragePrice  TotalVolume  PLU4046  PLU4225  PLU4770  \
# 11874   11/8/15          1.59        84.56     3.95     3.95      0.0
# 8788     1/4/15          1.73       379.82     0.00    59.82      0.0
# 11925  10/30/16          1.58       385.55     8.13    47.42      0.0
#
#        SmallBags  LargeBags  XLargeBags     Type             Region
# 11874      73.33       3.33         0.0  organic  MiamiFtLauderdale
# 8788      320.00       0.00         0.0  organic   BuffaloRochester
# 11925     330.00       0.00         0.0  organic  MiamiFtLauderdale

# %%
dfRegional.nlargest(3,'TotalVolume')
# Out:
#         Date  AveragePrice  TotalVolume     PLU4046     PLU4225    PLU4770  \
# 1123  2/5/17          0.67  11213596.29  3986429.59  3550403.07  214137.93
# 1175  2/4/18          0.80  10894677.77  4473811.63  4097591.67  146357.78
# 1071  2/7/16          0.70  10361698.17  2930343.28  3950852.38  424389.60
#
#        SmallBags  LargeBags  XLargeBags          Type      Region
# 1123  3403581.49    7838.83    51205.38  conventional  California
# 1175  2072477.62   34196.27    70242.80  conventional  California
# 1071  2693843.02  344774.59    17495.30  conventional  California

# %%
dfOrg = dfRegional[dfRegional.Type == 'organic']
dfOrg.head()
# Out:
#          Date  AveragePrice  TotalVolume  PLU4046  PLU4225  PLU4770  \
# 7943   1/4/15          1.79      1373.95    57.42   153.88      0.0
# 7944  1/11/15          1.77      1182.56    39.00   305.12      0.0
# 7945  1/18/15          1.93      1118.47     8.02   178.78      0.0
# 7946  1/25/15          1.89      1115.89    14.87   148.72      0.0
# 7947   2/1/15          1.83      1228.51    33.12    99.36      0.0
#
#       SmallBags  LargeBags  XLargeBags     Type  Region
# 7943    1162.65        0.0         0.0  organic  Albany
# 7944     838.44        0.0         0.0  organic  Albany
# 7945     931.67        0.0         0.0  organic  Albany
# 7946     952.30        0.0         0.0  organic  Albany
# 7947    1096.03        0.0         0.0  organic  Albany

# %%
dfConv = dfRegional[dfRegional.Type == 'conventional']
dfConv.head()
# Out:
#       Date  AveragePrice  TotalVolume  PLU4046   PLU4225  PLU4770  SmallBags  \
# 0   1/4/15          1.22     40873.28  2819.50  28287.42    49.90    9186.93
# 1  1/11/15          1.24     41195.08  1002.85  31640.34   127.12    8036.04
# 2  1/18/15          1.17     44511.28   914.14  31540.32   135.77   11651.09
# 3  1/25/15          1.06     45147.50   941.38  33196.16   164.14   10103.35
# 4   2/1/15          0.99     70873.60  1353.90  60017.20   179.32    9170.82
#
#    LargeBags  XLargeBags          Type  Region
# 0     529.53         0.0  conventional  Albany
# 1     388.73         0.0  conventional  Albany
# 2     269.96         0.0  conventional  Albany
# 3     742.47         0.0  conventional  Albany
# 4     152.36         0.0  conventional  Albany

# %%
# regions with the highest organic avocado sales by totalVolume
orgRegions = dfOrg.sort_values(by = 'TotalVolume', ascending = False).Region 
org_vol_max_regions = orgRegions.unique()[:5]
org_vol_max_regions
# Out:
# array(['NewYork', 'California', 'Denver', 'Seattle', 'LosAngeles'],
#       dtype=object)

# %%
# regions with the lowest conventional avocado sales by totalVolume
convRegions = dfConv.sort_values(by = 'TotalVolume').Region 
conv_vol_min_regions = convRegions.unique()[:5]
conv_vol_min_regions
# Out:
# array(['Syracuse', 'Albany', 'Spokane', 'Boise', 'Louisville'],
#       dtype=object)

# %% [markdown]
# ### Sorting
# For the following commands, use **`dfUS`**. Another way to determine the maximum and minimum values for a column is by sorting.
#
# * Let **`dfUS_sorted`** correspond to `dfUS` but with the rows sorted by `TotalVolume` in **decreasing order**.
# * Let **`vol_min_dates`** be an **array** containing the dates in the 5 rows with the highest `TotalVolume`. **Use `dfUS_sorted`.** (Can you guess why the volume was high on those dates?)

# %%
dfUS_sorted = dfUS.sort_values('TotalVolume', ascending = False)
dfUS_sorted.head()
# Out:
#         Date  AveragePrice  TotalVolume      PLU4046      PLU4225     PLU4770  \
# 7766  2/4/18          0.87  62505646.52  21620180.90  20445501.03  1066830.22
# 7714  2/5/17          0.77  61034457.10  22743616.17  20328161.55  1664383.09
# 7662  2/7/16          0.76  52288697.89  16573573.78  20470572.61  2546439.11
# 7727  5/7/17          1.09  47293921.60  17076650.82  13549102.59   863471.88
# 7675  5/8/16          0.82  46324529.70  14223304.98  17896391.60  1993645.36
#
#         SmallBags   LargeBags  XLargeBags          Type   Region
# 7766  13384586.80  5719096.61   269450.96  conventional  TotalUS
# 7714  12567155.58  3618270.75   112869.96  conventional  TotalUS
# 7662   9083373.04  3373077.87   241661.48  conventional  TotalUS
# 7727  11228049.63  4324231.19   252415.49  conventional  TotalUS
# 7675   8747756.84  3342780.83   120650.09  conventional  TotalUS

# %%
vol_min_dates = dfUS_sorted.head().Date
vol_min_dates
# Out:
# 7766    2/4/18
# 7714    2/5/17
# 7662    2/7/16
# 7727    5/7/17
# 7675    5/8/16
# Name: Date, dtype: object

# %% [markdown]
# ### Inserting New Columns
# * **Insert a new column `TotalBags`** which equals the sum of the `SmallBags`, `LargeBags`, and `XLargeBags` columns.
# * Check `.columns` to see that the column was added.

# %%
dfavo['TotalBags'] = sum([dfavo.SmallBags, dfavo.LargeBags, dfavo.XLargeBags])
dfavo.head()
# Out:
#       Date  AveragePrice  TotalVolume  PLU4046   PLU4225  PLU4770  SmallBags  \
# 0   1/4/15          1.22     40873.28  2819.50  28287.42    49.90    9186.93
# 1  1/11/15          1.24     41195.08  1002.85  31640.34   127.12    8036.04
# 2  1/18/15          1.17     44511.28   914.14  31540.32   135.77   11651.09
# 3  1/25/15          1.06     45147.50   941.38  33196.16   164.14   10103.35
# 4   2/1/15          0.99     70873.60  1353.90  60017.20   179.32    9170.82
#
#    LargeBags  XLargeBags          Type  Region  TotalBags
# 0     529.53         0.0  conventional  Albany    9716.46
# 1     388.73         0.0  conventional  Albany    8424.77
# 2     269.96         0.0  conventional  Albany   11921.05
# 3     742.47         0.0  conventional  Albany   10845.82
# 4     152.36         0.0  conventional  Albany    9323.18

# %%
dfavo.columns
# Out:
# Index(['Date', 'AveragePrice', 'TotalVolume', 'PLU4046', 'PLU4225', 'PLU4770',
#        'SmallBags', 'LargeBags', 'XLargeBags', 'Type', 'Region', 'TotalBags'],
#       dtype='object')

# %% [markdown]
# ### Summing Columns
# * Verify that the sum of the `TotalBags` column equals the sum of the `SmallBags`, `LargeBags`, and `XLargeBags` columns.

# %%
dfavo.TotalBags.sum() == (dfavo.SmallBags.sum() + dfavo.LargeBags.sum() + dfavo.XLargeBags.sum())
# Out:
# True

# %% [markdown]
# ### Sorting by Date
# For the following commands, use **`dfavo`**.
# * **Sort the dataframe by `Date`** in increasing order. Note that the first few dates are from 2017 and the last few are from 2015, because the dates are not stored in an appropriate format.
# * Run **`dfavo.dtypes`**. Note that the data type for the `Date` column is `object`.
# * **Change the data type of `Date`** by executing
# ```
# dfavo.Date = dfavo.Date.astype('datetime64[ns]')
# ```
# * Check that the `Date` type has been updated.
# * Let **`dfavo_sorted_dates`** correspond to `dfavo` but with the rows sorted chronologically by `Date`. Verify that the first few dates are from January 2015 and the last few from March 2018.
# * Note that this change did not affect the data type of `Date` in `dfRegional`.

# %%
dfavo.Date = dfavo.Date.astype('datetime64[ns]')

# %%
dfavo.sort_values('Date', ascending = False).head()
# Out:
#             Date  AveragePrice  TotalVolume      PLU4046      PLU4225  \
# 15882 2018-03-25          1.62     15303.40      2325.30      2171.66
# 7773  2018-03-25          1.03  43409835.75  14130799.10  12125711.42
# 5576  2018-03-25          1.06    658169.39     75837.48    304991.92
# 5745  2018-03-25          1.24    362959.17     91484.37    120803.28
# 5914  2018-03-25          1.10    316217.11     77628.91     88215.28
#
#          PLU4770    SmallBags   LargeBags  XLargeBags          Type  \
# 15882       0.00     10569.80      236.64        0.00       organic
# 7773   758801.12  12540327.19  3544729.39   309467.53  conventional
# 5576    14300.89    166273.14    96427.92      338.04  conventional
# 5745     5307.11    139121.67     6242.74        0.00  conventional
# 5914     1928.80    135644.21    11246.17     1553.74  conventional
#
#                   Region    TotalBags
# 15882   WestTexNewMexico     10806.44
# 7773             TotalUS  16394524.11
# 5576            Portland    263039.10
# 5745   RaleighGreensboro    145364.41
# 5914     RichmondNorfolk    148444.12

# %%
dfavo.sort_values('Date', ascending = False).tail()
# Out:
#             Date  AveragePrice  TotalVolume    PLU4046    PLU4225   PLU4770  \
# 10478 2015-01-04          1.68      2896.72     161.68     206.96      0.00
# 10647 2015-01-04          2.32      4801.10      87.56    4364.01      0.00
# 2197  2015-01-04          1.01    369694.27  121634.27  117865.11  74062.76
# 14534 2015-01-04          1.49     33795.91    6821.76   20720.77      1.23
# 0     2015-01-04          1.22     40873.28    2819.50   28287.42     49.90
#
#        SmallBags  LargeBags  XLargeBags          Type               Region  \
# 10478    2528.08       0.00        0.00       organic   HarrisburgScranton
# 10647     349.53       0.00        0.00       organic  HartfordSpringfield
# 2197    46679.86    1060.51     8391.76  conventional              Detroit
# 14534     452.73    5799.42        0.00       organic              Seattle
# 0        9186.93     529.53        0.00  conventional               Albany
#
#        TotalBags
# 10478    2528.08
# 10647     349.53
# 2197    56132.13
# 14534    6252.15
# 0        9716.46

# %%
dfavo_sorted_dates = dfavo.sort_values('Date', ascending = False)

# %% [markdown]
# ### Plotting DataFrames
#
# * Let **`dfdenverConv`** represent the rows for conventional avocados in the `Denver` region.
# * Let **`dfdenverOrg`** represent the rows for organic avocados in the `Denver` region.
#
# The following code plots a line graph showing the `TotalVolume` for conventional avocados in the Denver region over time.
# ```
# dfdenverConv.plot('Date', 'TotalVolume')
# ```
# **Plot line graphs** for Denver conventional and organic avocados `TotalVolume` by executing this code and adding the `label=` parameter for the legend.
# ```
# ax = dfdenverConv.plot('Date', 'TotalVolume')
# dfdenverOrg.plot('Date', 'TotalVolume', ax=ax)
# ```
# <img src="http://www.coloradomath.org/python/denver-avo-total-vol.jpg" width="372" height="283" />
#
# **Plot line graphs for `AveragePrice`** in the Denver region.
#
# <img src="http://www.coloradomath.org/python/denver-avo-avg-price.jpg" width="372" height="273" />

# %%
dfdenverConv = dfavo_sorted_dates[(dfavo_sorted_dates.Region == 'Denver') & 
                                  (dfavo_sorted_dates.Type == 'conventional')]

# %%
dfdenverConv.head()
# Out:
#            Date  AveragePrice  TotalVolume    PLU4046    PLU4225   PLU4770  \
# 2196 2018-03-25          1.02    950483.37  176286.79  222958.27  16540.62
# 2195 2018-03-18          1.02   1010953.71  163394.48  260747.73  15483.84
# 2194 2018-03-11          1.16    788107.23  159389.01  205340.23  16598.60
# 2193 2018-03-04          1.01    934460.44  192776.45  258652.66  15526.86
# 2192 2018-02-25          0.99   1018614.31  166753.37  254657.74  14153.31
#
#       SmallBags  LargeBags  XLargeBags          Type  Region  TotalBags
# 2196  121655.40  413042.29        0.00  conventional  Denver  534697.69
# 2195  129403.31  441922.13        2.22  conventional  Denver  571327.66
# 2194  156327.39  250452.00        0.00  conventional  Denver  406779.39
# 2193  137337.91  330166.56        0.00  conventional  Denver  467504.47
# 2192  137052.52  445944.87       52.50  conventional  Denver  583049.89

# %%
dfdenverOrg = dfavo_sorted_dates[(dfavo_sorted_dates.Region == 'Denver') & 
                                  (dfavo_sorted_dates.Type == 'organic')]

# %%
dfdenverOrg.head()
# Out:
#             Date  AveragePrice  TotalVolume   PLU4046  PLU4225  PLU4770  \
# 10139 2018-03-25          1.60     24825.50   6516.40   685.92    44.09
# 10138 2018-03-18          1.67     21352.34  10539.17   797.06    33.21
# 10137 2018-03-11          1.59     31590.90   7032.90   640.35    52.08
# 10136 2018-03-04          1.55     24300.28   5776.81   588.50    10.66
# 10135 2018-02-25          1.39     36823.42   8387.30   751.32    24.81
#
#        SmallBags  LargeBags  XLargeBags     Type  Region  TotalBags
# 10139   16514.58    1064.51         0.0  organic  Denver   17579.09
# 10138    9087.45     895.45         0.0  organic  Denver    9982.90
# 10137   23032.03     833.54         0.0  organic  Denver   23865.57
# 10136   17177.30     747.01         0.0  organic  Denver   17924.31
# 10135   26783.45     876.54         0.0  organic  Denver   27659.99

# %%
ax = dfdenverConv.plot('Date', 'TotalVolume', label = 'Conventional')
dfdenverOrg.plot('Date', 'TotalVolume', ax=ax, label = 'Organic')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,6))
ax.plot(dfdenverConv['Date'], dfdenverConv['AveragePrice'], label='Conventional')
ax.plot(dfdenverOrg['Date'], dfdenverOrg['AveragePrice'], label='Conventional')
plt.legend()
plt.show()
